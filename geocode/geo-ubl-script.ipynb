# %%
import pandas as pd
import xlrd

# %%
df = pd.read_excel('yield2017.xlsx')

# %%
df.head()
# Out:
#    HiveID HarvestDate  Weight           HiveAddress   HiveCity HiveState
# 0     866  2017-02-08     NaN      160 Federal St.      Boston        MA
# 1     822  2017-03-01     NaN  101 Farmers Cliff Rd    Concord        MA
# 2     342  2017-03-06    10.5            Taj Boston     Boston        MA
# 3    1215  2017-03-06     NaN        147 Cushing St  Cambridge        MA
# 4     510  2017-03-07    23.5    100 Federal Street     Boston        MA

# %%
type(df['HiveCity'])
# Out:
# pandas.core.series.Series

# %%
address, city, state = df['HiveAddress'][0], df['HiveCity'][0], df['HiveState'][0]

# %%
city
# Out:
# 'Boston'

# %%
address + '' + city + ' ' + state
# Out:
# '160 Federal St. Boston MA'

# %%
# add this code to geopy to see what I get
complete_postal = address + '' + city + ' ' + state
complete_postal
# Out:
# '160 Federal St. Boston MA'

# %%
for index, row in df.iterrows():
    print(row['HiveAddress'], row['HiveCity'],row['HiveState'])
# Out:
# 160 Federal St.  Boston MA
# 101 Farmers Cliff Rd Concord MA
# Taj Boston Boston MA
# 147 Cushing St Cambridge MA
# 100 Federal Street Boston MA
# 100 Federal Street Boston MA
# 10 Channel Center Street Boston MA
# CBRE/New England Boston MA
# Sheraton Boston Hotel Boston MA
# 20 Lover’s Lane Southborough MA
# Henrietta’s Table/Charles Hotel Cambridge MA
# Henrietta’s Table/Charles Hotel Cambridge MA
# The Bostonian Hotel Boston MA
# The Gallows Boston MA
# 900 Washington St.  Wellesley MA
# 25 Beacon St.  Boston MA
# Prudential Center - Boston Properties Boston MA
# 15 Hubbard Park Rd Cambridge MA
# 15 Hubbard Park Rd Cambridge MA
# 88 Foster Street Cambridge MA
# nan Provincetown MA
# nan Provincetown MA
# 1400 Canton Ave Milton MA
# 31 Dudley Lane Marshfield MA
# 158 Sandwich Street Plymouth MA
# 128 Waterford Drive Hanover MA
# 30 Beach Street  Marion MA
# 33 Old Farm Road Newton Center MA
# 30 Castle View Drive Gloucester MA
# 69-67 Riverview St Gloucester MA
# ...

# %%
type(complete_postal)
# Out:
# str
